# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
path = 'YDbD1.png'

img = cv2.imread(path)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img_gray)
plt.show()
